# %%
from IPython.core.display import HTMLdata_uri_png = open("test01.png", "rb").read().encode("base64").replace("\n", "")img_tag = '<img src="data:image/png;base64,{0}"/>'.format(data_uri_png)HTML(data=img_tag)
# Out:
# &lt;IPython.core.display.HTML at 0x110c3ded0&gt;

# %%
data_uri_m4v = open("test.m4v", "rb").read().encode("base64").replace("\n", "")data_uri_mov = open("test.mov", "rb").read().encode("base64").replace("\n", "")data_uri_mp4 = open("test.mp4", "rb").read().encode("base64").replace("\n", "")data_uri_mpeg = open("test.mpeg", "rb").read().encode("base64").replace("\n", "")video_tag = """<video controls poster="data:image/png;base64,{png}"><source type = "video/x-m4v" src="data:video/x-m4v;base64,{m4v}"/><source type = "video/quicktime" src="data:video/quicktime;base64,{mov}"/><source type = "video/mp4" src="data:video/mp4;base64,{mp4}"/><source type = "video/mpeg" src="data:video/mpeg;base64,{mpeg}"/>Your  browser does not support the video tag</video>""".format(png=data_uri_png,                   m4v=data_uri_m4v,                   mov=data_uri_mov,                   mp4=data_uri_mp4,                   mpeg=data_uri_mpeg)HTML(data=video_tag)
# Out:
# &lt;IPython.core.display.HTML at 0x1114a5150&gt;

# %%
video_tag = """<video controls><source src="data:video/x-m4v;base64,{m4v}"/>Your browser does not support the video tag</video>""".format(m4v=data_uri_m4v)HTML(data=video_tag)
# Out:
# &lt;IPython.core.display.HTML at 0x110c36ed0&gt;

# %%
video_tag = """<video controls><source type ="video/mp4" src="data:video/mp4;base64,{mp4}"/>Your browser does not support the video tag</video>""".format(mp4=data_uri_mp4)HTML(data=video_tag)
# Out:
# &lt;IPython.core.display.HTML at 0x110c368d0&gt;

# %%
video_tag = """<video controls><source type = "video/mpeg" src="data:video/mpeg;base64,{mpeg}"/>Your browswer does not support the video tag</video>""".format(mpeg=data_uri_mpeg)HTML(data=video_tag)
# Out:
# &lt;IPython.core.display.HTML at 0x11149e110&gt;

# %%
video_tag = """<video controls><source src="data:video/quicktime;base64,{mov}"/>Your browser does not support the video tag</video>""".format(mov=data_uri_mov)HTML(data=video_tag)
# Out:
# &lt;IPython.core.display.HTML at 0x11149e190&gt;

# %%
HTML(data = """<!DOCTYPE html><html><body><svg id="svgelem" height="200" width="300" xmlns="http://www.w3.org/2000/svg"><ellipse cx="150" cy="75" rx="10" ry="40" fill="blue"><animate attributeName="rx" begin="0s" dur="10s"values="10;110;10"  repeatCount="indefinite"/></ellipse><g id="G"><rect x="85" y="130" height="20" width="60" fill="green"/><text x="90" y="148" font-size="20" fill="white">GO</text></g><g id="R"><rect x="150" y="130" height="20" width="60" fill="red"/><text x="155" y="148" font-size="20" fill="white">STOP</text></g></svg></body></html>""")
# Out:
# &lt;IPython.core.display.HTML at 0x110c36f10&gt;

# %%
from IPython.core.display import JavascriptJavascript(data="""document.write("Hello")""")
# Out:
# &lt;IPython.core.display.Javascript at 0x10426eed0&gt;

# %%
HTML(data="""<html><body>Hello<p id="demo">This is a paragraph</p><script type="text/javascript">//document.getElementById("demo").innerHTML="Goodbye"</script></body></html>""")
# Out:
# &lt;IPython.core.display.HTML at 0x104ad6750&gt;
