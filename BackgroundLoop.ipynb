# %%
# %pylab inlineimport sys, timeimport numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type 'help(pylab)'.

# %% [markdown]
# Create the Client and View:

# %%
from IPython import parallelrc = parallel.Client(profile="mpi")dv = rc[:]dv.block = Truedv.activate()dv
# Out:
# <DirectView [0, 1, 2, 3,...]>

# %% [markdown]
# Check for MPI.  It's fine for this example if we don't have it, but it will technically be possible forsimulation nodes to get slightly out of sync.

# %%
# %%pxtry:    from mpi4py import MPIexcept ImportError:    bcast = lambda buf: buf    barrier = lambda : None    rank = 0    print "No MPI, dummy sims may get slightly out of sync"else:    mpi = MPI.COMM_WORLD    bcast = mpi.bcast    barrier = mpi.barrier    rank = mpi.rank    print "MPI rank: %i/%i" % (mpi.rank,mpi.size)
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7][stdout:0] MPI rank: 1/8[stdout:1] MPI rank: 2/8[stdout:2] MPI rank: 6/8[stdout:3] MPI rank: 3/8[stdout:4] MPI rank: 4/8[stdout:5] MPI rank: 0/8[stdout:6] MPI rank: 7/8[stdout:7] MPI rank: 5/8

# %% [markdown]
# Quick test of the broadcast:

# %%
# %px bcast(rank)
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[13]: 0
# [1] Out[13]: 0
# [2] Out[13]: 0
# [3] Out[13]: 0
# [4] Out[13]: 0
# [5] Out[13]: 0
# [6] Out[13]: 0
# [7] Out[13]: 0

# %% [markdown]
# Define a function on the engines that holds the GIL for a period of time(like time.sleep, but holding the GIL to simulate blocking computation):

# %%
# %%pxfrom cython import inlinedef gilsleep(t):    """gil-holding sleep with cython.inline"""    code = '\n'.join([        'from posix cimport unistd',        'unistd.sleep(t)',    ])    inline(code, quiet=True, t=t)gilsleep(1)
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# And define our dummy simulation, which just refines the appropriate slice of sin(x),after grabbing the GIL for a period of time:

# %%
# %%pximport numpy as npclass DummySimulation(object):    def __init__(self, x1, x2, n, p, dt=1):        self.x1 = x1        self.x2 = x2        self.n = n        self.p = p        self.dt = dt        self.y = None        self.step = 0        def advance(self):        # include mpi barrier, for good measure        barrier()        self.step += 1        n = self.n        p = self.p        gilsleep(self.dt)        npoints = p * self.step        X = np.linspace(x1, x2, npoints)        x = X[n * npoints / p : (n+1) * npoints / p]        self.y = np.sin(x)        return self.step
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Set up the global state (we are just sampling sin(x) on an interval), and instantiate the Simulation objects:

# %%
x1 = 0x2 = 10*np.pidv['x1'] = x1dv['x2'] = x2dv.scatter('n', range(len(dv)), flatten=True)dv['p'] = len(dv)dv['step'] = 0%px sim = DummySimulation(x1, x2, n, p, dt=1)
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Take the first step, to make sure everything is in working order:

# %%
# %px sim.advance()
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[17]: 1
# [1] Out[17]: 1
# [2] Out[17]: 1
# [3] Out[17]: 1
# [4] Out[17]: 1
# [5] Out[17]: 1
# [6] Out[17]: 1
# [7] Out[17]: 1

# %% [markdown]
# This is the function we are going to use to inspect our intermediate result.It fetches the current value of the simulation step, and the value of 'y',and makes a plot.

# %%
from IPython.core.display import displaydef check_y():    """fetch and plot the current state of the simulation"""    states = dv.apply_sync(lambda : (sim.step, sim.y))    steps, ys = zip(*states)    Y = np.concatenate(ys)    X = linspace(0, 10*np.pi, len(Y))    fig = plt.figure()    plt.title("step %i (%i points)" % (steps[0], len(X)))    plt.plot(X, Y, 'o-')    display(fig)    plt.close(fig)

# %%
check_y()

# %% [markdown]
# ## Now the interesting part

# %% [markdown]
# Here we start a Thread that advances the simulation *in the background*.The engines should be responsive on the timescale of the gilsleep threshold (**1 seconds**, here):

# %%
# %%px --blockfrom threading import Threadclass BackgroundAdvance(Thread):    """Call a function periodically in a thread, until self.stop() is called"""    def __init__(self, advance):        Thread.__init__(self)        self._done = False        self._paused = False        self._advance = advance                def stop(self):        self._done = True        def pause(self):        self._paused = True        def resume(self):        self._paused = False        def run(self):        while True:            # all stop together:            self._done = bcast(self._done)            if self._done:                return            if self._paused:                barrier()                time.sleep(1)            else:                self._advance()sim_thread = BackgroundAdvance(sim.advance)sim_thread.start()
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Note how that cell actually finished running.Now the simulation is running in a background thread, and we can check in on it with out check_y():

# %%
for i in range(5):    check_y()    time.sleep(2)

# %% [markdown]
# And we can stop the background thread with a simple call:

# %%
# %px sim_thread.stop()
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# And hopefully all the engines are on the same step at the end:

# %%
# %px sim.step
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[20]: 37
# [1] Out[20]: 37
# [2] Out[20]: 37
# [3] Out[20]: 37
# [4] Out[20]: 37
# [5] Out[20]: 37
# [6] Out[20]: 37
# [7] Out[20]: 37

# %% [markdown]
# And hopefully they are all stopped, as well:

# %%
# %px sim_thread.is_alive()
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[21]: False
# [1] Out[21]: False
# [2] Out[21]: False
# [3] Out[21]: False
# [4] Out[21]: False
# [5] Out[21]: False
# [6] Out[21]: False
# [7] Out[21]: False

# %% [markdown]
# And we can continue to advance the sim manually, as well:

# %%
for i in range(5):    %px sim.advance()    check_y()    sys.stdout.flush()
# Out:
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[22]: 38
# [1] Out[22]: 38
# [2] Out[22]: 38
# [3] Out[22]: 38
# [4] Out[22]: 38
# [5] Out[22]: 38
# [6] Out[22]: 38
# [7] Out[22]: 38
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[23]: 39
# [1] Out[23]: 39
# [2] Out[23]: 39
# [3] Out[23]: 39
# [4] Out[23]: 39
# [5] Out[23]: 39
# [6] Out[23]: 39
# [7] Out[23]: 39
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[24]: 40
# [1] Out[24]: 40
# [2] Out[24]: 40
# [3] Out[24]: 40
# [4] Out[24]: 40
# [5] Out[24]: 40
# [6] Out[24]: 40
# [7] Out[24]: 40
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[25]: 41
# [1] Out[25]: 41
# [2] Out[25]: 41
# [3] Out[25]: 41
# [4] Out[25]: 41
# [5] Out[25]: 41
# [6] Out[25]: 41
# [7] Out[25]: 41
# Parallel execution on engine(s): [0, 1, 2, 3, 4, 5, 6, 7]
# [0] Out[26]: 42
# [1] Out[26]: 42
# [2] Out[26]: 42
# [3] Out[26]: 42
# [4] Out[26]: 42
# [5] Out[26]: 42
# ...
