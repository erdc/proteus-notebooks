# %%
log = open("ipynb.out","r").readlines()log[-100:]
# Out:
# ['    self.stream.read_until(b("\\r\\n\\r\\n"), self._header_callback)\n', '  File "/home/cekees/proteus/linux/lib/python2.7/site-packages/tornado/iostream.py", line 161, in read_until\n', '    if self._read_to_buffer() == 0:\n', '  File "/home/cekees/proteus/linux/lib/python2.7/site-packages/tornado/iostream.py", line 375, in _read_to_buffer\n', '    chunk = self._read_from_socket()\n', '  File "/home/cekees/proteus/linux/lib/python2.7/site-packages/tornado/iostream.py", line 635, in _read_from_socket\n', '    chunk = self.socket.read(self.read_chunk_size)\n', '  File "/home/cekees/proteus/linux/lib/python2.7/ssl.py", line 151, in read\n', '    return self._sslobj.read(len)\n', 'SSLError: [Errno 1] _ssl.c:1354: error:140780E5:SSL routines:SSL23_READ:ssl handshake failure\n', 'WARNING:root:Read error on 34: [Errno 1] _ssl.c:1354: error:140780E5:SSL routines:SSL23_READ:ssl handshake failure\n', 'ERROR:root:Error in connection callback\n', 'Traceback (most recent call last):\n', '  Fil
# ...
